# %%
import pandas as pd
import numpy as np
df= pd.read_csv("nhanes_2015_2016.csv")
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
df.plot.hexbin(x = 'BMXARMC', y='BMXLEG', gridsize = 20)
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARMC', y='BMXLEG', 
               C = 'BMXHT',
               reduce_C_function=np.max,
               gridsize = 15,
              figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARMC', y='BMXLEG', 
               C = 'BMXHT',
               reduce_C_function=np.max,
               gridsize = 15,
              figsize=(8, 6),
              cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARMC', y='BMXLEG', 
               C = 'BMXHT',
               reduce_C_function=np.max,
               gridsize = 15,
               edgecolors = 'face',
              figsize=(8, 6),
              cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARMC', y='BMXLEG', 
               C = 'BMXHT',
               reduce_C_function=np.max,
               gridsize = 20,
               edgecolors = 'face',
               mincnt = 10,
              figsize=(8, 6),
              cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nhanes_2015_2016.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
df.plot.hexbin(x='BMXWT', y='BMXHT', gridsize = 20)
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>

# %%
df.plot.hexbin(x='BMXWT', y='BMXHT', gridsize = (20, 20))
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>

# %%
df.plot.hexbin(x='BMXWT', y='BMXHT', C = "BMXBMI",
                gridsize = 20)
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>

# %%
df.plot.hexbin(x='BMXWT', y='BMXHT', C = "BMXBMI",
                gridsize = 30, cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>

# %%
df.plot.hexbin(x='BMXWT', y='BMXHT', C = "BMXBMI",
               reduce_C_function=np.mean,
                gridsize = 20, cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nhanes_2015_2016.csv")
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
df.plot.hexbin(x = 'BMXARML', y = 'BMXLEG', gridsize = 20)
# Out:
# <AxesSubplot:xlabel='BMXARML', ylabel='BMXLEG'>

# %%
df.plot.scatter(x = 'BMXARML', y = 'BMXLEG')
# Out:
# <AxesSubplot:xlabel='BMXARML', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARML', y = 'BMXLEG', C = "BMXHT",
               gridsize = 20,
              figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='BMXARML', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARML', y = 'BMXLEG', C = "BMXHT",
               gridsize = 20,
               cmap = 'viridis',
              figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='BMXARML', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x = 'BMXARML', y = 'BMXLEG', C = "BMXHT",
               gridsize = 20,
               cmap = 'viridis',
               mincnt = 5,
              figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='BMXARML', ylabel='BMXLEG'>
