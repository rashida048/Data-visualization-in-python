# %%
import numpy as np
import pandas as pd
df = pd.read_csv('../machineLearning/Andrew/nhanes_2015_2016.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.shape
# Out:
# (5735, 30)

# %%
pd.set_option('display.max.columns', None)

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
df["DMDEDUC2x"] = df.DMDEDUC2.replace({1: "less than 9", 2: "9-11", 3: "HS/GED", 4: "Some college/AA", 5: "College", 
                                       7: "Refused", 9: "Don't know"})
df["DMDMARTLx"] = df.DMDMARTL.replace({1: "Married", 2: "Widowed", 3: "Divorced", 4: "Separated", 5: "Never married",
                                      6: "Living w/partner", 77: "Refused"})

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210', 'DMDEDUC2x', 'DMDMARTLx'],
#       dtype='object')

# %%
df.head(50).plot(x='BMXWT', y = 'BMXWAIST')
# Out:
# <AxesSubplot:xlabel='BMXWT'>

# %%
df['BMXWT'].hist()
# Out:
# <AxesSubplot:>

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].plot(kind='hist', alpha=0.3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].plot.hist(stacked=True, bins=20, fontsize=12, figsize=(10, 8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].hist(bins=20,figsize=(10, 8))
# Out:
# array([[<AxesSubplot:title={'center':'BMXWT'}>,
#         <AxesSubplot:title={'center':'BMXHT'}>],
#        [<AxesSubplot:title={'center':'BMXBMI'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG']].diff().hist(bins=20,figsize=(10, 8))
# Out:
# array([[<AxesSubplot:title={'center':'BMXWT'}>,
#         <AxesSubplot:title={'center':'BMXHT'}>],
#        [<AxesSubplot:title={'center':'BMXBMI'}>,
#         <AxesSubplot:title={'center':'BMXLEG'}>]], dtype=object)

# %%
df[['DMDEDUC2x', 'BPXSY1']].hist(by='DMDEDUC2x', figsize=(18, 12))
# Out:
# array([[<AxesSubplot:title={'center':'9-11'}>,
#         <AxesSubplot:title={'center':'College'}>],
#        [<AxesSubplot:title={'center':"Don't know"}>,
#         <AxesSubplot:title={'center':'HS/GED'}>],
#        [<AxesSubplot:title={'center':'Some college/AA'}>,
#         <AxesSubplot:title={'center':'less than 9'}>]], dtype=object)

# %%
df[['DMDEDUC2x', 'BPXSY1']].hist(by='DMDEDUC2x', figsize=(18, 12))
# Out:
# array([[<AxesSubplot:title={'center':'9-11'}>,
#         <AxesSubplot:title={'center':'College'}>],
#        [<AxesSubplot:title={'center':"Don't know"}>,
#         <AxesSubplot:title={'center':'HS/GED'}>],
#        [<AxesSubplot:title={'center':'Some college/AA'}>,
#         <AxesSubplot:title={'center':'less than 9'}>]], dtype=object)

# %%
df_martst = df.groupby('DMDMARTLx')['BPXSY1'].mean()
df_martst
# Out:
# DMDMARTLx
# Divorced            130.376164
# Living w/partner    121.923077
# Married             125.280942
# Never married       121.282818
# Refused             124.000000
# Separated           128.023121
# Widowed             136.773333
# Name: BPXSY1, dtype: float64

# %%
df.groupby('DMDMARTLx')['BPXSY1'].mean().plot(kind='bar', rot=45, fontsize=10, figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='DMDMARTLx'>

# %%
df.groupby('DMDEDUC2x')['BPXSY1'].mean().plot(kind='barh', fontsize=10, figsize=(8, 6))
# Out:
# <AxesSubplot:ylabel='DMDEDUC2x'>

# %%
df_bmx = df.groupby('RIDRETH1')['BMXWT', 'BMXHT', 'BMXBMI'].mean().reset_index()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_bmx
# Out:
#    RIDRETH1      BMXWT       BMXHT     BMXBMI
# 0         1  81.400300  161.916650  30.965900
# 1         2  79.388338  162.695442  29.928150
# 2         3  83.703412  169.103730  29.199559
# 3         4  86.330687  168.457415  30.399751
# 4         5  71.365436  164.598322  26.152125

# %%
df_bmx.reset_index().plot(x = 'RIDRETH1', 
            y=['BMXWT', 'BMXHT', 'BMXBMI'], 
            kind = 'bar', 
            color = ['lightblue', 'red', 'yellow'], 
            fontsize=10)
# Out:
# <AxesSubplot:xlabel='RIDRETH1'>

# %%
df_bmx.reset_index().plot(x = 'RIDRETH1', 
            y=['BMXWT', 'BMXHT', 'BMXBMI'], 
            kind = 'bar', stacked=True,
            color = ['lightblue', 'red', 'yellow'], 
            fontsize=10)
# Out:
# <AxesSubplot:xlabel='RIDRETH1'>

# %%
df_sm = df.groupby('SMQ020')['BPXSY1', 'BPXDI1', 'BPXSY2', 'BPXDI2'].mean().reset_index()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_sm
# Out:
#    SMQ020      BPXSY1     BPXDI1      BPXSY2     BPXDI2
# 0       1  127.593651  69.852154  127.219599  69.398664
# 1       2  123.350690  69.292346  123.096617  69.344102
# 2       7  106.000000  60.000000  142.000000  27.000000
# 3       9  127.142857  67.142857  128.857143  66.000000

# %%
df_sm.reset_index().plot(x = 'SMQ020', 
            y=['BPXSY1', 'BPXDI1'], 
            kind = 'bar', stacked=True,
            color = ['lightgreen', 'pink'], 
            fontsize=10)
# Out:
# <AxesSubplot:xlabel='SMQ020'>

# %%
df_sm.reset_index().plot(x = 'SMQ020', 
            y=['BPXSY1', 'BPXDI1'], 
            kind = 'bar',
            color = ['lightgreen', 'pink'], 
            fontsize=10)
# Out:
# <AxesSubplot:xlabel='SMQ020'>

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210', 'DMDEDUC2x', 'DMDMARTLx'],
#       dtype='object')

# %%
df.head(300).plot(x='BMXBMI', y= 'BPXSY1', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='BMXBMI', ylabel='BPXSY1'>

# %%
df_edu_marit = df.groupby('DMDEDUC2x')['DMDMARTL'].count()
pd.Series(df_edu_marit)
# Out:
# DMDEDUC2x
# 9-11                643
# College            1366
# Don't know            3
# HS/GED             1186
# Some college/AA    1621
# less than 9         655
# Name: DMDMARTL, dtype: int64

# %%
ax = pd.Series(df_edu_marit).plot.pie(subplots=True, label='',
                                      labels = ['College Education', 'high school', 
                                                'less than high school', 'Some college',
                                               'HS/GED', 'Unknown'],
                                      figsize = (8, 6),
                                     colors = ['lightgreen', 'violet', 'coral', 'skyblue', 'yellow', 'purple'],
                                     autopct = '%.2f')

# %%
color = {'boxes': 'DarkBlue', 'whiskers': 'coral', 
         'medians': 'Black', 'caps': 'Green'}
df[['BMXBMI', 'BMXLEG', 'BMXARML']].plot.box(figsize=(8, 6),color=color)
# Out:
# <AxesSubplot:>

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange', 
         'medians': 'DarkBlue', 'caps': 'Gray'}
df[['BMXBMI', 'BMXLEG', 'BMXARML']].plot.box(figsize=(8, 6),
                                             color=color,
                                            sym = 'r+')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210', 'DMDEDUC2x', 'DMDMARTLx'],
#       dtype='object')

# %%
df.head(500).plot.scatter(x= 'BMXWT', y = 'BMXHT', c ='BMXLEG', s=50, 
                          figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>

# %%
df.head(200).plot.scatter(x= 'BMXHT', y = 'BMXWT', 
                          s =df['BMXBMI'][:200] * 7, 
                          alpha=0.5, color='purple',
                         figsize=(8, 6))
# Out:
# <AxesSubplot:xlabel='BMXHT', ylabel='BMXWT'>

# %%
df.head(1000).plot.hexbin(x='BMXARMC', y='BMXLEG', gridsize=25)
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x='BMXARMC', y='BMXLEG', gridsize= 20)
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x='BMXARMC', y='BMXLEG', C = 'BMXHT',
                         reduce_C_function=np.max,
                         gridsize=15,
                        figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.plot.hexbin(x='BMXARMC', y='BMXLEG', C = 'BMXHT',
                         reduce_C_function=np.max,
                         gridsize=15,
                        figsize=(8,6),
                        cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
df.head(500).plot.hexbin(x='BMXARMC', y='BMXLEG',
                         reduce_C_function=np.max,
                         gridsize=20,
                        figsize=(8,6),
                        cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='BMXARMC', ylabel='BMXLEG'>

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df[['BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML']],
               alpha = 0.2, figsize=(10, 8), diagonal = 'kde')
# Out:
# array([[<AxesSubplot:xlabel='BMXWT', ylabel='BMXWT'>,
#         <AxesSubplot:xlabel='BMXHT', ylabel='BMXWT'>,
#         <AxesSubplot:xlabel='BMXBMI', ylabel='BMXWT'>,
#         <AxesSubplot:xlabel='BMXLEG', ylabel='BMXWT'>,
#         <AxesSubplot:xlabel='BMXARML', ylabel='BMXWT'>],
#        [<AxesSubplot:xlabel='BMXWT', ylabel='BMXHT'>,
#         <AxesSubplot:xlabel='BMXHT', ylabel='BMXHT'>,
#         <AxesSubplot:xlabel='BMXBMI', ylabel='BMXHT'>,
#         <AxesSubplot:xlabel='BMXLEG', ylabel='BMXHT'>,
#         <AxesSubplot:xlabel='BMXARML', ylabel='BMXHT'>],
#        [<AxesSubplot:xlabel='BMXWT', ylabel='BMXBMI'>,
#         <AxesSubplot:xlabel='BMXHT', ylabel='BMXBMI'>,
#         <AxesSubplot:xlabel='BMXBMI', ylabel='BMXBMI'>,
#         <AxesSubplot:xlabel='BMXLEG', ylabel='BMXBMI'>,
#         <AxesSubplot:xlabel='BMXARML', ylabel='BMXBMI'>],
#        [<AxesSubplot:xlabel='BMXWT', ylabel='BMXLEG'>,
#         <AxesSubplot:xlabel='BMXHT', ylabel='BMXLEG'>,
# ...

# %%
df['BMXWT'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[['BMXWT', 'BMXHT', 'BMXBMI']].plot.kde(figsize = (8, 6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves
data = pd.read_csv('../iris.csv')
data.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
andrews_curves(df[['BPXSY1', 'BPXDI1', 'BPXSY2','BPXDI2', 'DMDEDUC2x']].dropna(), 'DMDEDUC2x')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210', 'DMDEDUC2x', 'DMDMARTLx'],
#       dtype='object')

# %%
from pandas.plotting import parallel_coordinates

parallel_coordinates(df[['BMXWT', 'BMXHT', 'BMXBMI', 'RIAGENDR']].dropna().head(200), 'RIAGENDR', 
                     color=['blue', 'violet'])
# Out:
# <AxesSubplot:>

# %%
from pandas.plotting import lag_plot

lag_plot(df['BPXSY1'], alpha=0.5)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from pandas.plotting import autocorrelation_plot
data = 0.7 * np.random.rand(len(df)) + 0.3*np.sin(df['BMXBMI'])

autocorrelation_plot(data)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from pandas.plotting import bootstrap_plot

bootstrap_plot(df['BMXBMI'], size=100, samples=500, color='skyblue')

# %%
len(df)
# Out:
# 5735

# %%
from pandas.plotting import radviz
radviz(df[['BPXSY1', 'BPXDI1', 'BPXSY2','BPXDI2', 'DMDEDUC2x']].dropna(), 'DMDEDUC2x')
# Out:
# <AxesSubplot:>
